# %%
class Point:

  def __init__(self,x,y):
    self.x_cod = x
    self.y_cod = y

  def __str__(self):
    return '<{},{}>'.format(self.x_cod,self.y_cod)

  def euclidean_distance(self,other):
    return ((self.x_cod - other.x_cod)**2 + (self.y_cod - other.y_cod)**2)**0.5

  def distance_from_origin(self):
    return (self.x_cod**2 + self.y_cod**2)**0.5
    # return self.euclidean_distance(Point(0,0))


class Line:

  def __init__(self,A,B,C):
    self.A = A
    self.B = B
    self.C = C

  def __str__(self):
    if self.C < 0:
      return '{}x + {}y - {} = 0'.format(self.A, self.B, abs(self.C) )
    else:
      return '{}x + {}y + {} = 0'.format(self.A, self.B, self.C)



  def point_on_line(line,point):
    if line.A * point.x_cod + line.B * point.y_cod + line.C == 0:
      return "lies on the line"
    else:
      return "Does not lies on the line"




l1 = Line(1,1,-2)
p1 = Point(1,1)


print(l1)
print(p1)
print(l1.point_on_line(p1))
# Out:
# 1x + 2y + 3 = 0

# %%
#Reference Variable


class Person:
    def __init__(self):
        self.name = "Salman"
        self.gender = "Male"

p = Person()
#p is just a variable which contains the refrence/address of object - Person

#mutliple refrence

x = Person()
y = x
print(id(x)) #it will be same as y
print(id(y)) #it will be same as x
# Out:
# 5304384928
# 5304384928

# %%
#pass by refrence

class Person:
    def __init__(self,name,gender):
        self.name = name
        self.gender = gender

#outisde of the class -> function
def greet(person):
    print(f"Hello my name is {person.name} and I am a {person.gender}")

p = Person("Muffakir",'male')

greet(p)


def return_func():
    p1 = Person('Salman',"Male")
    return p1

x = return_func()
print(x.name)

# %%
#Object ki mutability
class Person:
    def __init__(self,name,gender):
        self.name = name
        self.gender = gender

#outisde of the class -> function
def greet(person):
    person.name = "salman"
    return person

p = Person("Muffakir",'male')
print((p.name))
p1 = greet(p)
print((p1.name))
# Out:
# Muffakir
# salman

# %%
#Encapsulation


#Instance Variable : for every object the value of instance var is different

# Encapsulation in Python is the concept of hiding internal object details (like variables)
# and restricting direct access to them. It protects data by allowing access only through
# defined methods (getters/setters), ensuring better control and security.











class Atm:

  # constructor(special function)->superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0 #__ makes an var or function private
    #self.menu()

  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

obj1 = Atm()
obj1.__balance = "hehe"
obj1.withdraw()

# %%
#Collection of Objects
class Person:
    def __init__(self,name,gender):
        self.name = name
        self.gender = gender


p1 = Person('muffakir','male')
p2 = Person('salman','male')
p3 = Person('faheem','male')


d = {'p1' :p1,'p2': p2, 'p3' : p3}


for i in d:
    print(d[i].gender)

# %%
#Encapsulation


#Instance Variable : for every object the value of instance var is different



class Atm:
  __counter = 1
  # constructor(special function)->superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0 #__ makes an var or function private
    self.cid = Atm.__counter
    Atm.__counter = Atm.__counter + 1
    #self.menu()

  #you can access static method just by calling the class.
  @staticmethod
  def get_counter():
        return Atm.__counter

  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

obj1 = Atm()
obj2 = Atm()
obj3 = Atm()


print(Atm.get_counter())
print(Atm.get_counter())
print(Atm.get_counter())
# Out:
# 4736874784
# 4731962336
# 4475491232
# 4
# 4
# 4

# %%
#Instance var : har object ke liye alag hota hai | object ka hota hai 
#Static var : har object ke liye same hota | class ka hota hai | methods ke bahar define hota hai
