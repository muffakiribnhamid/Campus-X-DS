# %%
# What is Pandas
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language

# %%
# Pandas Series
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %%
#importing pandas
import numpy as np
import pandas as pd

# %%
#series from list

# %%
#strings
country = ["India","Pak","USA","Nepal"]
pd.Series(country)
# Out:
# 0    India
# 1      Pak
# 2      USA
# 3    Nepal
# dtype: object

# %%
#intergers
runs = [12,23,243,2,232,101]
pd.Series(runs)
# Out:
# 0     12
# 1     23
# 2    243
# 3      2
# 4    232
# 5    101
# dtype: int64

# %%
#customs index
marks = [100,90,67,100,100,56]
subjects = ["Science","English","Urdu","Math","CS","Hindi"]

pd.Series(marks,index=subjects)
# Out:
# Science    100
# English     90
# Urdu        67
# Math       100
# CS         100
# Hindi       56
# dtype: int64

# %%
#setting a name
marks = [100,90,67,100,100,56]
subjects = ["Science","English","Urdu","Math","CS","Hindi"]

pd.Series(marks,index=subjects,name="Muffakir ke marks")
# Out:
# Science    100
# English     90
# Urdu        67
# Math       100
# CS         100
# Hindi       56
# Name: Nithish ke marks, dtype: int64

# %%
#series from dict

marks = {
    "maths":67,
    "english":100,
    "science":98,
    "urdu":100,
    "sst":100
}

marks_series = pd.Series(marks,name="X ke marks")
marks_series
# Out:
# maths       67
# english    100
# science     98
# urdu       100
# sst        100
# Name: X ke marks, dtype: int64

# %%
#SERIES Attributes:

# %%
#1.size -> returns size of series or returns items
marks_series.size
# Out:
# 5

# %%
#2-dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
#is_unique: tells if all items in series are unique

marks_series.is_unique
# Out:
# False

# %%
#index -> gives back index array of all indexes

marks_series.index
# Out:
# Index(['maths', 'english', 'science', 'urdu', 'sst'], dtype='object')

# %%
#values -> gives back array of values
marks_series.values
# Out:
# array([ 67, 100,  98, 100, 100])

# %%
#series using read_csv
pd.read_csv("smartphone_cleaned_v5.csv")
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999    81.0    True
# 4       realme               Realme 10 Pro Plus  24999    82.0    True
# ..         ...                              ...    ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 976      honor                      Honor X8 5G  14990    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %%
pd.read_csv("smartphone_cleaned_v5.csv",usecols=["model", "price"])
# Out:
#                                model  price
# 0                      OnePlus 11 5G  54999
# 1          OnePlus Nord CE 2 Lite 5G  19989
# 2              Samsung Galaxy A14 5G  16499
# 3               Motorola Moto G62 5G  14999
# 4                 Realme 10 Pro Plus  24999
# ..                               ...    ...
# 975       Motorola Moto Edge S30 Pro  34990
# 976                      Honor X8 5G  14990
# 977  POCO X4 GT 5G (8GB RAM + 256GB)  28990
# 978             Motorola Moto G91 5G  19990
# 979           Samsung Galaxy M52s 5G  24990
#
# [980 rows x 2 columns]

# %%
#converting data frame into series

phones = pd.read_csv("smartphone_cleaned_v5.csv",index_col='rating',usecols=["model", "price","rating"]).squeeze()

# %%
#Head and tail

# %%
#head -> first 5 rows by default or param to sepcify

# %%
phones.head()
# Out:
#                             model  price
# rating
# 89.0                OnePlus 11 5G  54999
# 81.0    OnePlus Nord CE 2 Lite 5G  19989
# 75.0        Samsung Galaxy A14 5G  16499
# 81.0         Motorola Moto G62 5G  14999
# 82.0           Realme 10 Pro Plus  24999

# %%
#tail -> last 5 rows
phones.tail()
# Out:
#                                   model  price
# rating
# 83.0         Motorola Moto Edge S30 Pro  34990
# 75.0                        Honor X8 5G  14990
# 85.0    POCO X4 GT 5G (8GB RAM + 256GB)  28990
# 80.0               Motorola Moto G91 5G  19990
# 74.0             Samsung Galaxy M52s 5G  24990

# %%
#sample
#gives one random row

phones.sample()
# Out:
#                                    model  price
# rating
# 84.0    Poco X4 Pro 5G (8GB RAM + 128GB)  17999

# %%
pd.read_csv("movies.csv")
# Out:
#          imdbId                              title  releaseYear  releaseDate  \
# 0     tt0118578                             Albela         2001  20 Apr 2001
# 1     tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2     tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3     tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4     tt0227194                         One 2 Ka 4         2001  30 Mar 2001
# ...         ...                                ...          ...          ...
# 1279  tt4121522               Shuruaat Ka Interval         2014  15 Aug 2014
# 1280  tt4187650                   Trip to Bhangarh         2014  28 Aug 2014
# 1281  tt4190220                           Zed Plus         2014  28 Nov 2014
# 1282  tt4219300                    Gollu aur Pappu         2014  21 Nov 2014
# 1283  tt4228746                                Zid         2014  28 Nov 2014
#
#                             genre  \
# ...

# %%
movies = pd.read_csv("movies.csv",usecols=["title","actors","genre"],index_col=["title"])

# %%
#value_counts -> gets the frequency count
actors = pd.read_csv("actors.csv")
actors.value_counts()
# Out:
# actorId  actorName       movieCount  ratingSum  normalizedMovieRank  googleHits  normalizedGoogleRank  normalizedRating
# 373      Aamir Khan      11          1170       9.44862              2460000     7.34283               10.00000            1
# 525      Mahie Gill      7           230        2.25776              111000      1.28292               2.44801             1
# 511      Vrajesh Hirjee  8           300        2.71196              12300       1.02830               2.56175             1
# 514      Arbaaz Khan     17          530        2.09335              235000      1.60282               2.53662             1
# 517      Udita Goswami   9           280        2.08696              229000      1.58734               2.52416             1
#                                                                                                                           ..
# ...

# %%
vk = pd.read_csv("vk.csv").squeeze()
x = vk.iloc[0]
x
# Out:
# Runs                   12
# BF                     22
# 4s                      1
# 6s                      0
# SR                  54.54
# Pos                   2.0
# Dismissal             lbw
# Inns                    1
# Opposition    v Sri Lanka
# Ground           Dambulla
# Start Date      18-Aug-08
# Name: 0, dtype: object

# %%
#sort values -> temporary change btw
vk.sort_values(by="Runs",ascending=False).head(1).values[0][0]
# Out:
# 154

# %%
vk.sort_values(by="Runs",inplace=True)

# %%
vk
# Out:
#      Runs   BF  4s  6s      SR  Pos Dismissal  Inns      Opposition  \
# 52      0    5   0   0    0.00  3.0    bowled     1       v England
# 97      0    3   0   0    0.00  3.0    caught     1       v England
# 42      0    1   0   0    0.00  3.0       lbw     2   v West Indies
# 68      0    5   0   0    0.00  3.0    bowled     1      v Pakistan
# 91      0    5   0   0    0.00  3.0    caught     2  v South Africa
# ..    ...  ...  ..  ..     ...  ...       ...   ...             ...
# 66    128  119  12   1  107.56  3.0   not out     2     v Sri Lanka
# 96    136  122  16   2  111.47  3.0    bowled     2    v Bangladesh
# 117   138  140   6   5   98.57  3.0    caught     1  v South Africa
# 108   139  126  12   3  110.31  4.0   not out     2     v Sri Lanka
# 126   154  134  16   1  114.92  3.0   not out     2   v New Zealand
#
#             Ground Start Date
# 52         Kolkata  25-Oct-11
# 97         Cardiff  27-Aug-14
# 42     North Sound  11-Jun-11
# ...

# %%
#sort index -> sorts based on index

movies.sort_index(inplace=True)

# %%
#series math methods

# %%
#count

type(vk)
# Out:
# pandas.core.frame.DataFrame
