# %%
# Write a function get_final_line(filename), which takes filename as input and return final line of the file.
# Note: You can choose any file of your choice.

def get_final_line(filename):
    final_line = ""
    for current_line in open(filename,"r"):
        final_line = current_line
    return final_line

get_final_line("sample.txt")
# Out:
# 'Muffakir'

# %%
# Read through a text file, line by line. Use a dict to keep track of how many times each vowel
# (a, e, i, o, and u) appears in the file.
# Print the resulting tabulation -- dictionary.


def read_file(filename):
    vowels = ["a","e","i","o","u"]
    d = {i:0 for i in vowels}
    for current_line in open(filename,'r'):
        for ch in current_line:
            if ch in vowels:
                d[ch] += 1

    return d
        
read_file("sample.txt")
# Out:
# {'a': 2, 'e': 2, 'i': 1, 'o': 2, 'u': 1}

# %%
filename = "column.txt"
with open(filename,"w") as c:
    for i in range(1,11,2):
        lines = f"{i}\t {i+1}\n"
        c.writelines(lines)


with open(filename,"r") as f:
    lines = f.read().splitlines()
    
total = 0
with open(filename,"w") as f:
    for line in lines:
        a,b = line.split(sep="\t")
        res = int(a) * int(b)
        total += res
        f.write(f"{a}\t{b}\t{res}")
        f.write("Total\t"+str(total))


sum_columns()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[32], line 21
#      17         f.write(f"{a}\t{b}\t{res}")
#      18         f.write("Total\t"+str(total))
# ---> 21 sum_columns()
#
# Cell In[29], line 10, in sum_columns()
#       6         c.writelines(lines)
#       9 with open(filename,"w") as f:
# ---> 10     lines = f.read().splitlines()
#      12 total = 0
#      13 with open(filename,"w") as f:
#
# UnsupportedOperation: not readable
